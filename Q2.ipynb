# %%
import matplotlib.pyplot as plt

f = open("sample_AAPL.txt", "r")
listItems = f.read().splitlines()
appleprices=listItems
for i in range(0, len(listItems)): 
 appleprices[i] = float(listItems[i])

# %%
x_values = list(range(1, len(appleprices) + 1))
plt.plot(x_values, appleprices, marker='o', linestyle='-')
plt.xlabel('Day')
plt.ylabel('Trading prices')
plt.title('Apple Stock Price, Nov 2019 to Nov 2020')
plt.show()
